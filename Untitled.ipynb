# %%
import os
os.listdir()
import pandas as pd

# %%
ds = pd.read_json("in.json")
ds
# Out:
#            city      lat      lng country iso2   admin_name capital  \
# 0         Delhi  28.6600  77.2300   India   IN        Delhi   admin
# 1        Mumbai  18.9667  72.8333   India   IN  Mahārāshtra   admin
# 2       Kolkāta  22.5411  88.3378   India   IN  West Bengal   admin
# 3     Bangalore  12.9699  77.5980   India   IN    Karnātaka   admin
# 4       Chennai  13.0825  80.2750   India   IN   Tamil Nādu   admin
# ..          ...      ...      ...     ...  ...          ...     ...
# 182      Panaji  15.4800  73.8300   India   IN          Goa   admin
# 183       Damān  20.4170  72.8500   India   IN      Gujarāt   admin
# 184   Kavaratti  10.5626  72.6369   India   IN  Lakshadweep   admin
# 185   Panchkula  30.6915  76.8537   India   IN      Haryāna   minor
# 186  Kagaznāgār  19.3316  79.4661   India   IN    Telangana   minor
#
#     population population_proper
# 0     29617000          16753235
# 1     23355000          12478447
# 2     17560000           4496694
# ...

# %%
inpop = list(ds["population"])
inlat = list(ds["lat"])
inlng = list(ds["lng"])

# %%
inlat
inlng
# Out:
# [77.23,
#  72.8333,
#  88.3378,
#  77.598,
#  80.275,
#  78.4667,
#  73.8553,
#  72.58,
#  72.83,
#  80.947,
#  75.8667,
#  80.3311,
#  82.58,
#  79.0831,
#  77.4167,
#  75.8472,
#  73.2,
#  83.3167,
#  77.4167,
#  73.8131,
#  85.1414,
#  75.8486,
#  78.02,
#  73.1602,
#  78.1194,
#  86.1833,
#  73.7833,
#  77.3167,
#  75.32,
#  70.7984,
#  77.7,
#  79.9333,
#  72.9633,
#  86.435,
#  81.84,
#  83.0128,
#  74.8061,
#  74.85,
#  78.08,
#  73.0667,
#  78.1931,
#  81.4333,
#  88.31,
#  85.3347,
#  80.6167,
#  76.7911,
#  76.6531,
#  81.6337,
#  75.83,
#  79.415,
#  73.0168,
#  76.9667,
#  91.77,
#  91.7667,
#  75.9167,
#  78.6928,
#  75.125,
#  75.5792,
#  85.8281,
#  72.85,
#  78.7568,
#  74.2333,
#  76.8997,
#  77.546,
#  79.6011,
#  78.1667,
#  74.55,
#  76.2833,
#  83.3667,
#  75.56,
#  77.3398,
#  80.45,
#  84.8828,
#  74.8806,
#  77.3333,
#  85.8667,
#  79.3,
#  78.029,
#  87.32,
#  86.9667,
#  72.1369,
#  77.75,
#  79.9667,
#  74.639,
#  77.7081,
#  73.3169,
#  91.2667,
# ...

# %%
inlng = list(ds["city"])

# %%
inlng
# Out:
# ['Delhi',
#  'Mumbai',
#  'Kolkāta',
#  'Bangalore',
#  'Chennai',
#  'Hyderābād',
#  'Pune',
#  'Ahmadābād',
#  'Sūrat',
#  'Lucknow',
#  'Jaipur',
#  'Cawnpore',
#  'Mirzāpur',
#  'Nāgpur',
#  'Ghāziābād',
#  'Indore',
#  'Vadodara',
#  'Vishākhapatnam',
#  'Bhopāl',
#  'Chinchvad',
#  'Patna',
#  'Ludhiāna',
#  'Āgra',
#  'Kalyān',
#  'Madurai',
#  'Jamshedpur',
#  'Nāsik',
#  'Farīdābād',
#  'Aurangābād',
#  'Rājkot',
#  'Meerut',
#  'Jabalpur',
#  'Thāne',
#  'Dhanbād',
#  'Allahābād',
#  'Vārānasi',
#  'Srīnagar',
#  'Amritsar',
#  'Alīgarh',
#  'Bhiwandi',
#  'Gwalior',
#  'Bhilai',
#  'Hāora',
#  'Rānchi',
#  'Bezwāda',
#  'Chandīgarh',
#  'Mysore',
#  'Raipur',
#  'Kota',
#  'Bareilly',
#  'Jodhpur',
#  'Coimbatore',
#  'Dispur',
#  'Guwāhāti',
#  'Solāpur',
#  'Trichinopoly',
#  'Hubli',
#  'Jalandhar',
#  'Bhubaneshwar',
#  'Bhayandar',
#  'Morādābād',
#  'Kolhāpur',
#  'Thiruvananthapuram',
#  'Sahāranpur',
#  'Warangal',
#  'Salem',
#  'Mālegaon',
#  'Kochi',
# ...
